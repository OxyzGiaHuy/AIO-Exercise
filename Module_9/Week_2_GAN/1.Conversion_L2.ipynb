# %%
import torch
from torch import nn, Tensor
import numpy as np
from torchvision.utils import save_image

device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %% [markdown]
# # 1. Dataset

# %%
import torchvision

img_size = 32
    
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((img_size, img_size)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean=[0.5], std=[0.5])
])

images = torchvision.datasets.MNIST(root='mnist_data', train=True, 
                                    download=True, transform=transform)

# %%
BATCH_SIZE = 64
dataloader = torch.utils.data.DataLoader(images, batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# # 2. Model

# %%
channels = 1
img_shape = (channels, img_size, img_size)
latent_dim = 100

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(512, 1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.2, inplace=True),
        
            nn.Linear(1024, int(np.prod(img_shape))),
            nn.Tanh()
        )
        
    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), *img_shape)
        return img

# %%
generator = Generator()
generator.to(device)
# Out:
# Generator(
#   (model): Sequential(
#     (0): Linear(in_features=100, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1024, bias=True)
#     (9): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Linear(in_features=1024, out_features=1024, bias=True)
#     (12): Tanh()
#   )
# )

# %% [markdown]
# # 3. Training

# %%
import os
os.makedirs("images_l2", exist_ok=True)
save_interval = 10

# %%
EPOCHS = 200
optimizer_G = torch.optim.Adam(generator.parameters(), lr=0.0001)
criterion = nn.MSELoss()
hist = {
        "train_G_loss": []
}

for epoch in range(EPOCHS):
    total_loss = 0.0

    for i, (imgs, _) in enumerate(dataloader):

        real_imgs = imgs.to(device)

        # --- Train Generator --- 
        optimizer_G.zero_grad()
        
        # Noise input for Generator
        z = torch.randn((imgs.shape[0], latent_dim)).to(device)

        gen_imgs = generator(z)
        G_loss = criterion(gen_imgs, real_imgs)
        total_loss += G_loss.item()

        G_loss.backward()
        optimizer_G.step()

    
    total_loss = total_loss / len(dataloader)    
    print(f"Epoch [{epoch + 1}/{EPOCHS}], total_loss: {total_loss:.4f}")

    hist["train_G_loss"].append(total_loss)

    if epoch % save_interval == 0:
        save_image(gen_imgs.data[:25], f"images_l2/epoch_{epoch}.png", nrow=5, normalize=True)
# Out:
# Epoch [1/200], total_loss: 0.2267
# Epoch [2/200], total_loss: 0.2265
# Epoch [3/200], total_loss: 0.2265
# Epoch [4/200], total_loss: 0.2264
# Epoch [5/200], total_loss: 0.2263
# Epoch [6/200], total_loss: 0.2263
# Epoch [7/200], total_loss: 0.2263
# Epoch [8/200], total_loss: 0.2262
# Epoch [9/200], total_loss: 0.2262
# Epoch [10/200], total_loss: 0.2262
# Epoch [11/200], total_loss: 0.2261
# Epoch [12/200], total_loss: 0.2261
# Epoch [13/200], total_loss: 0.2261
# Epoch [14/200], total_loss: 0.2260
# Epoch [15/200], total_loss: 0.2260
# Epoch [16/200], total_loss: 0.2260
# Epoch [17/200], total_loss: 0.2260
# Epoch [18/200], total_loss: 0.2260
# Epoch [19/200], total_loss: 0.2260
# Epoch [20/200], total_loss: 0.2260
# Epoch [21/200], total_loss: 0.2260
# Epoch [22/200], total_loss: 0.2260
# Epoch [23/200], total_loss: 0.2259
# Epoch [24/200], total_loss: 0.2260
# Epoch [25/200], total_loss: 0.2260
# Epoch [26/200], total_loss: 0.2259
# Epoch [27/200], total_loss: 0.2259
# Epoch [28/200], total_loss: 0.2259
# Epoch [29/200], total_loss: 0.2259
# Epoch [30/200], total_loss: 0.2259
# Epoch [31/200], total_loss: 0.2259
# Epoch [32/200], total_loss: 0.2259
# Epoch [33/200], total_loss: 0.2259
# Epoch [34/200], total_loss: 0.2259
# Epoch [35/200], total_loss: 0.2259
# Epoch [36/200], total_loss: 0.2259
# Epoch [37/200], total_loss: 0.2259
# Epoch [38/200], total_loss: 0.2259
# Epoch [39/200], total_loss: 0.2259
# Epoch [40/200], total_loss: 0.2259
# Epoch [41/200], total_loss: 0.2259
# Epoch [42/200], total_loss: 0.2259
# Epoch [43/200], total_loss: 0.2259
# Epoch [44/200], total_loss: 0.2259
# Epoch [45/200], total_loss: 0.2259
# Epoch [46/200], total_loss: 0.2259
# Epoch [47/200], total_loss: 0.2259
# Epoch [48/200], total_loss: 0.2259
# Epoch [49/200], total_loss: 0.2259
# Epoch [50/200], total_loss: 0.2259
# Epoch [51/200], total_loss: 0.2259
# Epoch [52/200], total_loss: 0.2259
# Epoch [53/200], total_loss: 0.2259
# Epoch [54/200], total_loss: 0.2259
# Epoch [55/200], total_loss: 0.2259
# Epoch [56/200], total_loss: 0.2259
# Epoch [57/200], total_loss: 0.2259
# Epoch [58/200], total_loss: 0.2259
# Epoch [59/200], total_loss: 0.2259
# Epoch [60/200], total_loss: 0.2259
# Epoch [61/200], total_loss: 0.2259
# Epoch [62/200], total_loss: 0.2259
# Epoch [63/200], total_loss: 0.2259
# Epoch [64/200], total_loss: 0.2259
# Epoch [65/200], total_loss: 0.2259
# Epoch [66/200], total_loss: 0.2259
# Epoch [67/200], total_loss: 0.2259
# Epoch [68/200], total_loss: 0.2259
# Epoch [69/200], total_loss: 0.2259
# Epoch [70/200], total_loss: 0.2259
# Epoch [71/200], total_loss: 0.2259
# Epoch [72/200], total_loss: 0.2259
# Epoch [73/200], total_loss: 0.2259
# Epoch [74/200], total_loss: 0.2259
# Epoch [75/200], total_loss: 0.2259
# Epoch [76/200], total_loss: 0.2259
# Epoch [77/200], total_loss: 0.2259
# Epoch [78/200], total_loss: 0.2259
# Epoch [79/200], total_loss: 0.2259
# Epoch [80/200], total_loss: 0.2259
# Epoch [81/200], total_loss: 0.2259
# Epoch [82/200], total_loss: 0.2259
# Epoch [83/200], total_loss: 0.2259
# Epoch [84/200], total_loss: 0.2259
# Epoch [85/200], total_loss: 0.2259
# Epoch [86/200], total_loss: 0.2259
# Epoch [87/200], total_loss: 0.2259
# Epoch [88/200], total_loss: 0.2259
# Epoch [89/200], total_loss: 0.2259
# Epoch [90/200], total_loss: 0.2259
# Epoch [91/200], total_loss: 0.2259
# Epoch [92/200], total_loss: 0.2259
# Epoch [93/200], total_loss: 0.2259
# Epoch [94/200], total_loss: 0.2259
# Epoch [95/200], total_loss: 0.2259
# Epoch [96/200], total_loss: 0.2259
# Epoch [97/200], total_loss: 0.2259
# Epoch [98/200], total_loss: 0.2259
# Epoch [99/200], total_loss: 0.2259
# Epoch [100/200], total_loss: 0.2259
# Epoch [101/200], total_loss: 0.2259
# Epoch [102/200], total_loss: 0.2259
# Epoch [103/200], total_loss: 0.2259
# Epoch [104/200], total_loss: 0.2259
# Epoch [105/200], total_loss: 0.2259
# Epoch [106/200], total_loss: 0.2259
# Epoch [107/200], total_loss: 0.2259
# Epoch [108/200], total_loss: 0.2259
# Epoch [109/200], total_loss: 0.2259
# Epoch [110/200], total_loss: 0.2259
# Epoch [111/200], total_loss: 0.2259
# Epoch [112/200], total_loss: 0.2259
# Epoch [113/200], total_loss: 0.2259
# Epoch [114/200], total_loss: 0.2259
# Epoch [115/200], total_loss: 0.2259
# Epoch [116/200], total_loss: 0.2259
# Epoch [117/200], total_loss: 0.2259
# Epoch [118/200], total_loss: 0.2259
# Epoch [119/200], total_loss: 0.2259
# Epoch [120/200], total_loss: 0.2259
# Epoch [121/200], total_loss: 0.2259
# Epoch [122/200], total_loss: 0.2259
# Epoch [123/200], total_loss: 0.2259
# Epoch [124/200], total_loss: 0.2259
# Epoch [125/200], total_loss: 0.2259
# Epoch [126/200], total_loss: 0.2259
# Epoch [127/200], total_loss: 0.2259
# Epoch [128/200], total_loss: 0.2259
# Epoch [129/200], total_loss: 0.2259
# Epoch [130/200], total_loss: 0.2259
# Epoch [131/200], total_loss: 0.2259
# Epoch [132/200], total_loss: 0.2259
# Epoch [133/200], total_loss: 0.2259
# Epoch [134/200], total_loss: 0.2259
# Epoch [135/200], total_loss: 0.2259
# Epoch [136/200], total_loss: 0.2259
# Epoch [137/200], total_loss: 0.2259
# Epoch [138/200], total_loss: 0.2259
# Epoch [139/200], total_loss: 0.2259
# Epoch [140/200], total_loss: 0.2259
# Epoch [141/200], total_loss: 0.2259
# Epoch [142/200], total_loss: 0.2259
# Epoch [143/200], total_loss: 0.2259
# Epoch [144/200], total_loss: 0.2259
# Epoch [145/200], total_loss: 0.2259
# Epoch [146/200], total_loss: 0.2259
# Epoch [147/200], total_loss: 0.2259
# Epoch [148/200], total_loss: 0.2259
# Epoch [149/200], total_loss: 0.2259
# Epoch [150/200], total_loss: 0.2259
# Epoch [151/200], total_loss: 0.2259
# Epoch [152/200], total_loss: 0.2259
# Epoch [153/200], total_loss: 0.2259
# Epoch [154/200], total_loss: 0.2259
# Epoch [155/200], total_loss: 0.2259
# Epoch [156/200], total_loss: 0.2259
# Epoch [157/200], total_loss: 0.2259
# Epoch [158/200], total_loss: 0.2259
# Epoch [159/200], total_loss: 0.2259
# Epoch [160/200], total_loss: 0.2259
# Epoch [161/200], total_loss: 0.2259
# Epoch [162/200], total_loss: 0.2259
# Epoch [163/200], total_loss: 0.2259
# Epoch [164/200], total_loss: 0.2259
# Epoch [165/200], total_loss: 0.2259
# Epoch [166/200], total_loss: 0.2259
# Epoch [167/200], total_loss: 0.2259
# Epoch [168/200], total_loss: 0.2259
# Epoch [169/200], total_loss: 0.2259
# Epoch [170/200], total_loss: 0.2259
# Epoch [171/200], total_loss: 0.2259
# Epoch [172/200], total_loss: 0.2259
# Epoch [173/200], total_loss: 0.2259
# Epoch [174/200], total_loss: 0.2259
# Epoch [175/200], total_loss: 0.2259
# Epoch [176/200], total_loss: 0.2259
# Epoch [177/200], total_loss: 0.2259
# Epoch [178/200], total_loss: 0.2259
# Epoch [179/200], total_loss: 0.2259
# Epoch [180/200], total_loss: 0.2259
# Epoch [181/200], total_loss: 0.2259
# Epoch [182/200], total_loss: 0.2259
# Epoch [183/200], total_loss: 0.2259
# Epoch [184/200], total_loss: 0.2259
# Epoch [185/200], total_loss: 0.2259
# Epoch [186/200], total_loss: 0.2259
# Epoch [187/200], total_loss: 0.2259
# Epoch [188/200], total_loss: 0.2259
# Epoch [189/200], total_loss: 0.2259
# Epoch [190/200], total_loss: 0.2259
# Epoch [191/200], total_loss: 0.2259
# Epoch [192/200], total_loss: 0.2259
# Epoch [193/200], total_loss: 0.2259
# Epoch [194/200], total_loss: 0.2259
# Epoch [195/200], total_loss: 0.2259
# Epoch [196/200], total_loss: 0.2259
# Epoch [197/200], total_loss: 0.2259
# Epoch [198/200], total_loss: 0.2259
# Epoch [199/200], total_loss: 0.2259
# Epoch [200/200], total_loss: 0.2259
